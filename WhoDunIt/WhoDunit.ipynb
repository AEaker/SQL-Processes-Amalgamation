# %%
import sqlalchemy as sa
import pandas as pd
import datetime as dt
import numpy as np
import os

# %%
engine = sa.create_engine("mssql+pymssql://username:password@server/database", echo=True)

# %%
SelectQuery = '''SELECT
item_id, 
column_description,
key1_cd, key1_value,
key2_cd, key2_value,
key3_cd, key3_value,
old_value, new_value,
date_created, created_by
FROM p21_view_audit_trail_inv_mast_1314
WHERE created_by = 'person I'm auditing' AND
date_created between '02/01/2022' and '02/10/2022'
ORDER BY item_id ASC;
'''

# %%
AuditTrailQuery = pd.read_sql_query(SelectQuery, engine)
ChangedItems = pd.DataFrame(AuditTrailQuery)
ChangedItems
# Out:
# 2022-02-10 09:20:16,802 INFO sqlalchemy.engine.base.Engine select @@version
# 2022-02-10 09:20:16,803 INFO sqlalchemy.engine.base.Engine {}
# 2022-02-10 09:20:16,805 INFO sqlalchemy.engine.base.Engine SELECT schema_name()
# 2022-02-10 09:20:16,806 INFO sqlalchemy.engine.base.Engine {}
# 2022-02-10 09:20:16,808 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2022-02-10 09:20:16,809 INFO sqlalchemy.engine.base.Engine {}
# 2022-02-10 09:20:16,810 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS NVARCHAR(60)) AS anon_1
# 2022-02-10 09:20:16,810 INFO sqlalchemy.engine.base.Engine {}
# 2022-02-10 09:20:16,811 INFO sqlalchemy.engine.base.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2022-02-10 09:20:16,812 INFO sqlalchemy.engine.base.Engine {}
# 2022-02-10 09:20:16,814 INFO sqlalchemy.engine.base.OptionEngine SELECT
# item_id,
# column_description,
# key1_cd, key1_value,
# key2_cd, key2_value,
# ...

# %%
ChangedItems.to_excel('AuditTrail.xlsx', index=None)
